# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown

# %%
fig, ax = plt.subplots(figsize=(10, 8), layout='constrained')

x = np.arange(0.0, 1000, 0.1)
y = x**2 / (9.81 * 1000)

ax.plot(x, y, label='Теория')


# Рисуем оси
ax.spines[['top', 'right']].set_visible(False)
ax.spines[['top', 'right']].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')

# Рисуем стрелочки
arrow_fmt = dict(markersize=4, color='black', clip_on=False)
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

# Create 'x' and 'y' labels placed at the end of the axes
ax.set_xlabel('$V_0$ (м/с)', size=14, labelpad=0, x=0.95)
ax.set_ylabel('L (км)', size=14, labelpad=0, y=0.95, rotation=0)

# Create custom major ticks to determine position of tick labels
x_frequency, y_frequency = 200, 10 
xmin, xmax, ymin, ymax = 0, 1050, 0, 105

x_ticks = np.arange(xmin, xmax, x_frequency)
x_ticks_minor = np.arange(xmin, xmax, x_frequency/10)

y_ticks = np.arange(ymin, ymax, y_frequency)
y_ticks_minor = np.arange(ymin, ymax, y_frequency/5)

ax.set_xticks(x_ticks[x_ticks**2 > 0.005])
ax.set_yticks(y_ticks[y_ticks**2 > 0.005])
ax.set_xticks(x_ticks_minor, minor=True)
ax.set_yticks(y_ticks_minor, minor=True)
ax.grid(which='both')
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

ax.set_title('')
# ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8), layout='constrained')

x = np.arange(0.0, 0.51, 0.01)
y = 1000**2 * np.sin(2*x*np.pi)/ (9.81 * 1000)

ax.plot(x, y, label='Теория')


# Рисуем оси
ax.spines[['top', 'right']].set_visible(False)
ax.spines[['top', 'right']].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')

# Рисуем стрелочки
arrow_fmt = dict(markersize=4, color='black', clip_on=False)
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

# Create 'x' and 'y' labels placed at the end of the axes
ax.set_xlabel(r'$ \alpha (\pi рад) $', size=14, labelpad=0, x=0.95)
ax.set_ylabel('L (км)', size=14, labelpad=0, y=0.95, rotation=0)

# Create custom major ticks to determine position of tick labels
x_frequency, y_frequency = 0.1, 10.0 
xmin, xmax, ymin, ymax = 0, 0.53, 0, 105

x_ticks = np.arange(xmin, xmax, x_frequency)
x_ticks_minor = np.arange(xmin, xmax, x_frequency/10)

y_ticks = np.arange(ymin, ymax, y_frequency)
y_ticks_minor = np.arange(ymin, ymax, y_frequency/5)

ax.set_xticks(x_ticks[x_ticks**2 > 0.005])
ax.set_yticks(y_ticks[y_ticks**2 > 0.005])
ax.set_xticks(x_ticks_minor, minor=True)
ax.set_yticks(y_ticks_minor, minor=True)
ax.grid(which='both')
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)


ax.set_title('')
# ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8), layout='constrained')

v0 = 800
alpha = np.pi / 4
L = v0 ** 2  * np.sin(2*alpha) / (9.81)
print(L)
x = np.arange(0.0, L + 0.01, 0.01)
y = x*np.tan(alpha) - 9.81*x**2 / (2*v0**2 * np.cos(alpha)**2)
ax.plot(x, y, label=r'$V_0 = 100 (м/с)$', linestyle='-.')

v0 = 900
alpha = np.pi / 4
L = v0 ** 2  * np.sin(2*alpha) / (9.81)
print(L)
x = np.arange(0.0, L + 0.01, 0.01)
y = x*np.tan(alpha) - 9.81*x**2 / (2*v0**2 * np.cos(alpha)**2)
ax.plot(x, y, label=r'$V_0 = 500 (м/с)$', linestyle='--')

v0 = 1000
alpha = np.pi / 4
L = v0 ** 2  * np.sin(2*alpha) / (9.81)
print(L)
x = np.arange(0.0, L + 0.01, 0.01)
y = x*np.tan(alpha) - 9.81*x**2 / (2*v0**2 * np.cos(alpha)**2)
ax.plot(x, y, label=r'$V_0 = 1000 (м/с)$', linestyle='-')






# Рисуем оси
ax.spines[['top', 'right']].set_visible(False)
ax.spines[['top', 'right']].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')

# Рисуем стрелочки
arrow_fmt = dict(markersize=4, color='black', clip_on=False)
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

# Create 'x' and 'y' labels placed at the end of the axes
ax.set_xlabel(r'x (м)', size=14, labelpad=0, x=0.95)
ax.set_ylabel(r'h (м)', size=14, labelpad=0, y=0.95, rotation=0)

# Create custom major ticks to determine position of tick labels
#x_frequency, y_frequency = 200, 5 
#xmin, xmax, ymin, ymax = 0, 1050, 0, 27

#x_ticks = np.arange(xmin, xmax, x_frequency)
#x_ticks_minor = np.arange(xmin, xmax, x_frequency/5)

#y_ticks = np.arange(ymin, ymax, y_frequency)
#y_ticks_minor = np.arange(ymin, ymax, y_frequency/5)

#ax.set_xticks(x_ticks[x_ticks**2 > 0.005])
#ax.set_yticks(y_ticks[y_ticks**2 > 0.005])
#ax.set_xticks(x_ticks_minor, minor=True)
#ax.set_yticks(y_ticks_minor, minor=True)
#ax.grid(which='both')
#ax.grid(which='minor', alpha=0.2)
#ax.grid(which='major', alpha=0.5)

ax.set_title('')
ax.legend()

plt.show()
# Out:
# 65239.55147808359
# 82568.80733944954
# 101936.7991845056

# %%
fig, ax = plt.subplots(figsize=(10, 8), layout='constrained')

v0 = 1000
alpha = np.pi / 8
L = v0 ** 2  * np.sin(2*alpha) / (9.81)
print(L)
x = np.arange(0.0, L + 0.01, 0.01)
y = x*np.tan(alpha) - 9.81*x**2 / (2*v0**2 * np.cos(alpha)**2)
ax.plot(x, y, label=r'$\alpha = \frac {\pi}{8}$', linestyle='-.')

v0 = 1000
alpha = np.pi / 6
L = v0 ** 2  * np.sin(2*alpha) / (9.81)
print(L)
x = np.arange(0.0, L + 0.01, 0.01)
y = x*np.tan(alpha) - 9.81*x**2 / (2*v0**2 * np.cos(alpha)**2)
ax.plot(x, y, label=r'$\alpha = \frac {\pi}{6}$', linestyle='--')

v0 = 1000
alpha = np.pi / 4
L = v0 ** 2  * np.sin(2*alpha) / (9.81)
print(L)
x = np.arange(0.0, L + 0.01, 0.01)
y = x*np.tan(alpha) - 9.81*x**2 / (2*v0**2 * np.cos(alpha)**2)
ax.plot(x, y, label=r'$\alpha = \frac {\pi}{4}$', linestyle='-')






# Рисуем оси
ax.spines[['top', 'right']].set_visible(False)
ax.spines[['top', 'right']].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')

# Рисуем стрелочки
arrow_fmt = dict(markersize=4, color='black', clip_on=False)
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

# Create 'x' and 'y' labels placed at the end of the axes
ax.set_xlabel(r'x (м)', size=14, labelpad=0, x=0.95)
ax.set_ylabel(r'h (м)', size=14, labelpad=0, y=0.95, rotation=0)

# Create custom major ticks to determine position of tick labels
#x_frequency, y_frequency = 200, 5 
#xmin, xmax, ymin, ymax = 0, 1050, 0, 27

#x_ticks = np.arange(xmin, xmax, x_frequency)
#x_ticks_minor = np.arange(xmin, xmax, x_frequency/5)

#y_ticks = np.arange(ymin, ymax, y_frequency)
#y_ticks_minor = np.arange(ymin, ymax, y_frequency/5)

#ax.set_xticks(x_ticks[x_ticks**2 > 0.005])
#ax.set_yticks(y_ticks[y_ticks**2 > 0.005])
#ax.set_xticks(x_ticks_minor, minor=True)
#ax.set_yticks(y_ticks_minor, minor=True)
#ax.grid(which='both')
#ax.grid(which='minor', alpha=0.2)
#ax.grid(which='major', alpha=0.5)

ax.set_title('')
ax.legend()

plt.show()
# Out:
# 72080.20195581524
# 88279.8576742547
# 101936.7991845056
